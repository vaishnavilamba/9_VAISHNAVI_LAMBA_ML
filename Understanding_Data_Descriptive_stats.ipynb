# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavilamba/9_VAISHNAVI_LAMBA_ML/blob/main/Understanding_Data_Descriptive_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Descriptive statistics summarize your data.
#
# They answer questions like:
# How big are the values?
# What’s the average?
# How spread out is the data?
# Are there weird values (outliers)?

# %%
import pandas as pd

# %% [markdown]
# Reads a CSV file and converts it into a table-like structure.

# %%
df = pd.read_csv('train.csv')
df

# %% [markdown]
# 1. How big is the data?

# %%
df.shape

# %% [markdown]
#  2. How does the data look like?

# %%
df.sample(5)

# %% [markdown]
# 3. What is the data type of cols?

# %%
df.info()

# %% [markdown]
# 4. Are there any missing values?

# %%
df.isnull().sum()

# %% [markdown]
# 5. How does the data look mathematically?

# %%
df.describe()

# %% [markdown]
# 6. Are there duplicate values?

# %%
df.duplicated().sum()

# %% [markdown]
#  7. How is the correlation between cols?

# %%
df.corr()['Survived']
