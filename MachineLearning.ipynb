# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavilamba/9_VAISHNAVI_LAMBA_ML/blob/main/MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas**

# %% [markdown]
# Series--

# %%
import pandas as pd
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
