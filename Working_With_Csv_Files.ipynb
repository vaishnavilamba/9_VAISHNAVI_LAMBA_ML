# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavilamba/9_VAISHNAVI_LAMBA_ML/blob/main/Working_With_Csv_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Importing pandas

# %%
import pandas as pd

# %% [markdown]
# 2. opening a local csv file

# %%
df = pd.read_csv('aug_train.csv')
df

# %% [markdown]
# 3. Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)

pd.read_csv(data)

# %% [markdown]
# 4. Sep Parameter

# %%
pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])

# %% [markdown]
# 5. Index_col parameter

# %%
pd.read_csv('aug_train.csv',index_col='enrollee_id')

# %% [markdown]
# 6. Header parameter

# %%
pd.read_csv('test.csv',header=1,index_col='enrollee_id')

# %% [markdown]
# 7. use_cols parameter

# %%
pd.read_csv('aug_train.csv',usecols=['enrollee_id','gender','education_level'])

# %% [markdown]
# 8. Squeeze parametes

# %%
pd.read_csv('aug_train.csv',usecols=['gender'],squeeze=True)

# %% [markdown]
# 9. Skiprows/nrows Parameter

# %%
pd.read_csv('aug_train.csv',nrows=100)

# %% [markdown]
# 10. Encoding parameter

# %%
pd.read_csv('zomato.csv',encoding='latin-1')

# %% [markdown]
# 11. Skip bad lines

# %% [markdown]
# 12. dtypes parameter

# %%
pd.read_csv('aug_train.csv',dtype={'target' : int})

# %% [markdown]
# 13. Handling Dates

# %%
pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date']).info()

# %%
def rename(name):
  if name == "Royal Challengers Bangalore":
    return "RCB"
  else:
    return name

# %%
rename("Royal Challengers Bangalore")

# %% [markdown]
# 14. Convertors

# %%
pd.read_csv('IPL Matches 2008-2020.csv',converters={'team1':rename})

# %% [markdown]
# 15. na_values parameter

# %%
pd.read_csv('aug_train.csv',na_values=['Male',])

# %% [markdown]
# 16. Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('aug_train.csv',chunksize=5000)

# %%
for chunks in dfs:
    print(chunk.shape)
